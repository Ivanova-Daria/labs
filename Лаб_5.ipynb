# %% [markdown]
# <a href="https://colab.research.google.com/github/Ivanova-Daria/labs/blob/main/%D0%9B%D0%B0%D0%B1_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6ca3c3bc-83e7-489c-abec-0b1aee0abb6e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ca3c3bc-83e7-489c-abec-0b1aee0abb6e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving aug_train.csv to aug_train.csv

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
df=pd.read_csv('aug_train.csv', sep=',')

# %% [markdown]
# # **Box plots**

# %%
sns.boxplot(df['training_hours'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.kdeplot(df['training_hours'])

# %%
df.head()
# Out:
#    enrollee_id      city  ...  training_hours target
# 0         8949  city_103  ...              36    1.0
# 1        29725   city_40  ...              47    0.0
# 2        11561   city_21  ...              83    0.0
# 3        33241  city_115  ...              52    1.0
# 4          666  city_162  ...               8    0.0
#
# [5 rows x 14 columns]

# %% [markdown]
# # **Violin plot**

# %%
sns.violinplot(x='gender',y='training_hours', data =df)

# %% [markdown]
# # **Count plots**

# %%
sns.countplot(df['education_level'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **Heatmap**

# %%
sns.heatmap(df.corr(),annot=True,cmap='YlGnBu')

# %% [markdown]
# # **Facet grid**

# %%
g=sns.FacetGrid(df, col="target", row='gender')
g.map(plt.hist, 'training_hours')

# %% [markdown]
# # **Regplot**

# %%
df1 = df.copy(deep=True)

df1['experience']=df1['experience'].str.replace(r">","").str.replace(r"<","")
df1['experience']=df1['experience'].astype('float64')
df1['experience']=df1['experience'].fillna(0)

# %%
sns.regplot(x='training_hours', y='experience',data=df1)

# %% [markdown]
# # **lmplot**

# %%
sns.lmplot(x='training_hours', y='experience',row='target', data = df1, col='gender')

# %% [markdown]
# # **Swarm plot**

# %%
sns.swarmplot(x='experience',y='training_hours',data=df1)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 43.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 91.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 92.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 93.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.pairplot(data=df1)

# %%
sns.jointplot(x='experience',y='training_hours',data=df1)
